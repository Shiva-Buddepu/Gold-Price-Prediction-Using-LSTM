# %% [markdown]
# ##Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %% [markdown]
# ##Reading Dataset

# %%
df = pd.read_csv('Gold Price (2013-2023).csv')

# %% [markdown]
# ##Dataset Overview

# %%
df
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1     12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2     12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3     12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4     12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%
# ...          ...       ...       ...       ...       ...      ...      ...
# 2578  01/08/2013  1,663.20  1,651.50  1,662.60  1,648.80    0.13K    0.97%
# 2579  01/07/2013  1,647.20  1,657.30  1,663.80  1,645.30    0.09K   -0.16%
# 2580  01/04/2013  1,649.90  1,664.40  1,664.40  1,630.00    0.31K   -1.53%
# 2581  01/03/2013  1,675.60  1,688.00  1,689.30  1,664.30    0.19K   -0.85%
# 2582  01/02/2013  1,689.90  1,675.80  1,695.00  1,672.10    0.06K    0.78%
#
# [2583 rows x 7 columns]

# %% [markdown]
# ##Dataset Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %% [markdown]
# ##Data Preparation

# %%
# Feature Subset Selection
df.drop(['Vol.', 'Change %'], axis=1, inplace=True)

# %%
#Transforming Data
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %%
#Checking Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Checking Missing Values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Visualizing Gold Price History Data

# %%
#Interactive Gold Price Chart:

fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(255,223,0,0.8)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba078696-4faf-4b07-8055-070ae2250e02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba078696-4faf-4b07-8055-070ae2250e02")) {                    Plotly.newPlot(                        "ba078696-4faf-4b07-8055-070ae2250e02",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-04T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","20 ...

# %% [markdown]
# ##Splitting Data to Training & Test Sets

# %%
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %%
#Gold Price Training and Test Sets Plot

plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# ##Data Scaling

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %% [markdown]
# ##Restructure Data & Create Sliding Window

# %%
window_size = 60

# %%
#Training Set

train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
#Test Set

test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %% [markdown]
# ##Converting Data to Numpy Arrays

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %% [markdown]
# ##Creating an LSTM Network

# %%
#Model Definition:

def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
#Model Training:

model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,057 (332.25 KB)
#  Trainable params: 85,057 (332.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0748 - val_loss: 0.0773
# Epoch 2/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 0.0127 - val_loss: 0.0403
# Epoch 3/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 0.0080 - val_loss: 0.0199
# Epoch 4/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0060 - val_loss: 0.0086
# Epoch 5/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 6/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 7/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 8/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 9/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 10/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 11/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 12/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 13/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 14/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 15/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 16/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 17/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 18/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 9.5059e-04 - val_loss: 0.0060
# Epoch 19/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 9.3459e-04 - val_loss: 0.0024
# Epoch 20/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 8.8152e-04 - val_loss: 0.0011
# Epoch 21/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 9.3345e-04 - val_loss: 0.0023
# Epoch 22/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 9.0477e-04 - val_loss: 0.0020
# Epoch 23/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - loss: 7.5783e-04 - val_loss: 0.0080
# Epoch 24/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 8.2771e-04 - val_loss: 7.9671e-04
# Epoch 25/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.0454e-04 - val_loss: 0.0033
# Epoch 26/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 7.1402e-04 - val_loss: 0.0024
# Epoch 27/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.2251e-04 - val_loss: 0.0017
# Epoch 28/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 6.4347e-04 - val_loss: 0.0015
# Epoch 29/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 7.0828e-04 - val_loss: 9.3517e-04
# Epoch 30/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 6.6660e-04 - val_loss: 0.0020
# Epoch 31/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 6.0253e-04 - val_loss: 0.0021
# Epoch 32/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 6.8780e-04 - val_loss: 0.0018
# Epoch 33/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 6.4864e-04 - val_loss: 0.0010
# Epoch 34/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 6.2879e-04 - val_loss: 9.9332e-04
# Epoch 35/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 5.6484e-04 - val_loss: 7.0521e-04
# Epoch 36/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 5.7730e-04 - val_loss: 8.0920e-04
# Epoch 37/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.4364e-04 - val_loss: 0.0010
# Epoch 38/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 5.2774e-04 - val_loss: 0.0012
# Epoch 39/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 5.5489e-04 - val_loss: 6.4801e-04
# Epoch 40/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 5.4381e-04 - val_loss: 5.3018e-04
# Epoch 41/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 5.9327e-04 - val_loss: 8.4770e-04
# Epoch 42/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 5.0119e-04 - val_loss: 6.3253e-04
# Epoch 43/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.4702e-04 - val_loss: 6.0537e-04
# Epoch 44/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 5.2531e-04 - val_loss: 0.0017
# Epoch 45/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 5.2492e-04 - val_loss: 7.8060e-04
# Epoch 46/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 5.6705e-04 - val_loss: 5.2268e-04
# Epoch 47/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 4.6673e-04 - val_loss: 0.0017
# Epoch 48/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.7293e-04 - val_loss: 5.3980e-04
# Epoch 49/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 4.8818e-04 - val_loss: 6.6357e-04
# Epoch 50/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 4.9986e-04 - val_loss: 8.9778e-04
# Epoch 51/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 4.5003e-04 - val_loss: 5.8328e-04
# Epoch 52/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.8830e-04 - val_loss: 4.8372e-04
# Epoch 53/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 4.9923e-04 - val_loss: 7.1569e-04
# Epoch 54/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.6623e-04 - val_loss: 8.0381e-04
# Epoch 55/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 4.3716e-04 - val_loss: 9.7127e-04
# Epoch 56/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 4.5339e-04 - val_loss: 5.8480e-04
# Epoch 57/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 4.7574e-04 - val_loss: 5.6303e-04
# Epoch 58/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 4.2006e-04 - val_loss: 0.0021
# Epoch 59/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 4.2390e-04 - val_loss: 6.5611e-04
# Epoch 60/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.5045e-04 - val_loss: 6.6600e-04
# Epoch 61/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 4.2179e-04 - val_loss: 6.4238e-04
# Epoch 62/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.5735e-04 - val_loss: 0.0016
# Epoch 63/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 4.2292e-04 - val_loss: 6.4360e-04
# Epoch 64/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.6820e-04 - val_loss: 4.6079e-04
# Epoch 65/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.0794e-04 - val_loss: 5.9152e-04
# Epoch 66/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 4.7578e-04 - val_loss: 0.0012
# Epoch 67/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 4.5357e-04 - val_loss: 9.0363e-04
# Epoch 68/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 4.2203e-04 - val_loss: 4.7907e-04
# Epoch 69/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.2925e-04 - val_loss: 6.6117e-04
# Epoch 70/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.4990e-04 - val_loss: 9.8031e-04
# Epoch 71/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 4.4915e-04 - val_loss: 4.8905e-04
# Epoch 72/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 4.1095e-04 - val_loss: 4.1834e-04
# Epoch 73/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 4.2020e-04 - val_loss: 4.5008e-04
# Epoch 74/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.7066e-04 - val_loss: 6.2570e-04
# Epoch 75/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 4.0387e-04 - val_loss: 0.0022
# Epoch 76/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.9943e-04 - val_loss: 6.0383e-04
# Epoch 77/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 4.1864e-04 - val_loss: 4.9078e-04
# Epoch 78/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 4.1384e-04 - val_loss: 0.0011
# Epoch 79/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 3.5497e-04 - val_loss: 3.8565e-04
# Epoch 80/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.5054e-04 - val_loss: 0.0013
# Epoch 81/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.9607e-04 - val_loss: 0.0013
# Epoch 82/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.3268e-04 - val_loss: 0.0016
# Epoch 83/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.8397e-04 - val_loss: 5.6083e-04
# Epoch 84/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.1660e-04 - val_loss: 5.6111e-04
# Epoch 85/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.9398e-04 - val_loss: 0.0033
# Epoch 86/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.8723e-04 - val_loss: 7.9942e-04
# Epoch 87/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.6905e-04 - val_loss: 9.3733e-04
# Epoch 88/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 3.9236e-04 - val_loss: 5.3319e-04
# Epoch 89/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 3.6212e-04 - val_loss: 6.1891e-04
# Epoch 90/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.5465e-04 - val_loss: 0.0015
# Epoch 91/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.4581e-04 - val_loss: 5.2664e-04
# Epoch 92/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2019e-04 - val_loss: 0.0013
# Epoch 93/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.8480e-04 - val_loss: 4.6046e-04
# Epoch 94/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.8463e-04 - val_loss: 0.0011
# Epoch 95/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 3.9362e-04 - val_loss: 5.7353e-04
# Epoch 96/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.4373e-04 - val_loss: 6.0934e-04
# Epoch 97/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 3.6808e-04 - val_loss: 0.0017
# Epoch 98/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 3.3201e-04 - val_loss: 0.0010
# Epoch 99/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.4692e-04 - val_loss: 0.0016
# Epoch 100/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.4524e-04 - val_loss: 7.9257e-04
# Epoch 101/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.1691e-04 - val_loss: 7.5995e-04
# Epoch 102/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.3033e-04 - val_loss: 0.0012
# Epoch 103/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 3.6819e-04 - val_loss: 7.0287e-04
# Epoch 104/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 3.4442e-04 - val_loss: 0.0012
# Epoch 105/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.4423e-04 - val_loss: 9.1463e-04
# Epoch 106/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.3900e-04 - val_loss: 0.0010
# Epoch 107/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 3.3466e-04 - val_loss: 0.0012
# Epoch 108/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.7466e-04 - val_loss: 0.0013
# Epoch 109/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.5210e-04 - val_loss: 9.5529e-04
# Epoch 110/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 2.9838e-04 - val_loss: 0.0013
# Epoch 111/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.6539e-04 - val_loss: 0.0011
# Epoch 112/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 3.5198e-04 - val_loss: 0.0028
# Epoch 113/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.2453e-04 - val_loss: 6.2519e-04
# Epoch 114/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.2025e-04 - val_loss: 9.4121e-04
# Epoch 115/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 3.4411e-04 - val_loss: 0.0016
# Epoch 116/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.1425e-04 - val_loss: 0.0025
# Epoch 117/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 3.8531e-04 - val_loss: 8.9940e-04
# Epoch 118/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.7754e-04 - val_loss: 5.3350e-04
# Epoch 119/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 3.2308e-04 - val_loss: 0.0017
# Epoch 120/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 3.1301e-04 - val_loss: 0.0020
# Epoch 121/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.3904e-04 - val_loss: 6.6884e-04
# Epoch 122/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.4075e-04 - val_loss: 6.2604e-04
# Epoch 123/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.0735e-04 - val_loss: 0.0010
# Epoch 124/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 2.8729e-04 - val_loss: 0.0016
# Epoch 125/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.5191e-04 - val_loss: 0.0010
# Epoch 126/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 3.1729e-04 - val_loss: 0.0021
# Epoch 127/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 3.0236e-04 - val_loss: 7.2389e-04
# Epoch 128/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.1822e-04 - val_loss: 9.1404e-04
# Epoch 129/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 3.0129e-04 - val_loss: 0.0012
# Epoch 130/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 3.2580e-04 - val_loss: 0.0015
# Epoch 131/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.3123e-04 - val_loss: 0.0022
# Epoch 132/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 2.9870e-04 - val_loss: 0.0020
# Epoch 133/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.3096e-04 - val_loss: 0.0010
# Epoch 134/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.1795e-04 - val_loss: 7.9848e-04
# Epoch 135/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 2.9317e-04 - val_loss: 6.3989e-04
# Epoch 136/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.2604e-04 - val_loss: 0.0019
# Epoch 137/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 2.7913e-04 - val_loss: 0.0014
# Epoch 138/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 2.8900e-04 - val_loss: 8.7668e-04
# Epoch 139/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.0338e-04 - val_loss: 0.0013
# Epoch 140/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 2.7569e-04 - val_loss: 0.0020
# Epoch 141/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2.8982e-04 - val_loss: 0.0011
# Epoch 142/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 2.7614e-04 - val_loss: 0.0014
# Epoch 143/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 2.6981e-04 - val_loss: 0.0013
# Epoch 144/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.1837e-04 - val_loss: 0.0011
# Epoch 145/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 2.9993e-04 - val_loss: 0.0014
# Epoch 146/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 2.8140e-04 - val_loss: 0.0014
# Epoch 147/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.0887e-04 - val_loss: 0.0019
# Epoch 148/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 2.9712e-04 - val_loss: 0.0013
# Epoch 149/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 2.7241e-04 - val_loss: 0.0018
# Epoch 150/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.3223e-04 - val_loss: 0.0014

# %% [markdown]
# ##Model Evaluation

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.1787e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0010029999539256096
# Test MAPE: 0.03465929457209889
# Test Accuracy: 0.9653407054279011

# %% [markdown]
# ##Visualizing Results

# %%
#Returning the actual and predicted Price values to their primary scale
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
#Investigating the closeness of the prices predicted by the model to the actual prices
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
